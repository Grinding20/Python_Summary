# %%
fuhao = input('请输入一个符号：')
hangshu = int(input('请输入一个行数：'))
def lingxing(h,f):
    for i in range(h):
        print(' '*(h-i),(f+' ')*i)
    for i in range(h):
        print(' '*(i),(f+' ')*(h-i))
    return  ' '
print(lingxing(hangshu,fuhao))
# Out:
# 请输入一个符号：*
# 请输入一个行数：5
#
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *
#   * * * *
#    * * *
#     * *
#      *

# %%
# 非递归算法
def jiecheng_1(n):
    my_sum = 1
    for i in range(n):
        my_sum = my_sum * (i+1)
    return my_sum
    
def qiuhe_1(m):
    my_total = 0
    for i in range(m):
        my_total = my_total + jiecheng_1(i+1)
    return my_total
print(qiuhe_1(int(input('请输入一个整数：'))))

# %%
# 递归算法
def jiecheng_2(n):
    
    if n == 1:
        return 1
    else:
        return  n*jiecheng_2(n-1)

def qiuhe(n):
    if n == 1:
        return jiecheng_2(1)
    else:
        return jiecheng_2(n)+ qiuhe(n-1)
print(qiuhe(int(input('请输入一个数字'))))

# %%
list_1 = [i for i in range(10)]
#print(list_1)
list_2 = ['A','B','C','D','E','F','G','H','J','K','L','M','N','P','Q','R','S','T','U','V','W','X','Y','Z']
#print(list_2)
import random

my_set = set()
while True:
    X = str(random.choice(list_2))
    Y1 =  str(random.choice(list_1 + list_2))
    Y2 =  str(random.choice(list_1 + list_2))
    Y3 =  str(random.choice(list_1 + list_2))
    Y4 =  str(random.choice(list_1 + list_2))
    Y5 =  str(random.choice(list_1 + list_2))
    my_chepai = X+'-'+Y1+Y2+Y3+Y4+Y5
    my_set.add(my_chepai)
    if len(my_set)==10:
        break
your_list = list(my_set)
for i in range(10):
    a = int(i)
    print(a,':',your_list[i])

# %%
a = [1,2,3,4]
b = [4,5,6,7]
c = [7,8,9,10]
import math
x = ((3-1)*(6-4)+(4-2)*(7-5))/(math.sqrt((3-1)**2+(4-2)**2)*math.sqrt((6-4)**2+(7-5)**2))
print(x)
# Out:
# 0.9999999999999998

# %%
import random
A=[]
for i in range(100000):
    a=random.randint(1,10000)
    A.append(a)
numbers = A
numbers_dict_1={}
for num in numbers:
    if num in numbers_dict_1:
        numbers_dict_1 [num] += 1
    else:
        numbers_dict_1 [num] = 1
b = []        
for key, value in numbers_dict_1.items():  
    a = key, value
    b.append(a) 
    
fileObject = open('a.txt', 'w')  

for i in range(len(b)): 
    if i%2==0:
        fileObject.write(str(b[i])) 
        fileObject.write(',') 
    else:
        fileObject.write(str(b[i])) 
        fileObject.write('\n')  
fileObject.close()

# %%
import random
B=[]
for i in range(100000):
    b=random.randint(1,15000)
    B.append(b)
numbers = B
numbers_dict={}
for num in numbers:
    if num in numbers_dict:
        numbers_dict [num] += 1
    else:
        numbers_dict [num] = 1
d = []        
for key, value in numbers_dict.items():  
    c = key, value
    d.append(c) 
    
fileObject = open('b.txt', 'w')  

for i in range(len(d)): 
    if i%2==0:
        fileObject.write(str(d[i])) 
        fileObject.write(',') 
    else:
        fileObject.write(str(d[i])) 
        fileObject.write('\n')  
fileObject.close()

# %%
numbers_a = []
huiwen = []
for key, value in numbers_dict_1.items():  
    a = key, value
    numbers_a.append(a)
for i in range(len(numbers_a)):
    ha = len(str((numbers_a[i][0])))
    zi = str((numbers_a[i][0]))
    if ha==1:
        huiwen.append(numbers_a[i])
    elif ha==2 and zi[0]==zi[1]:
        huiwen.append(numbers_a[i])
    elif ha==3 and zi[0]==zi[2]:
        huiwen.append(numbers_a[i])
    elif ha == 4 and zi[0]==zi[3] and zi[1]==zi[2]:
        huiwen.append(numbers_a[i])
        
print( huiwen  )
# Out:
# [(212, 14), (606, 11), (3333, 12), (7887, 15), (262, 15), (636, 15), (282, 9), (5995, 7), (8558, 9), (5555, 8), (131, 8), (3663, 12), (717, 9), (909, 11), (8998, 13), (9, 11), (424, 5), (585, 10), (2332, 16), (77, 10), (969, 12), (454, 6), (373, 11), (4, 4), (1441, 9), (848, 10), (9999, 11), (141, 10), (999, 9), (646, 12), (6006, 15), (8, 10), (3883, 7), (5335, 9), (7997, 15), (303, 13), (878, 10), (292, 14), (191, 10), (7117, 10), (474, 14), (202, 12), (464, 7), (66, 12), (4554, 6), (181, 11), (989, 16), (5, 14), (343, 14), (6996, 13), (5225, 9), (727, 7), (6336, 14), (707, 12), (272, 9), (767, 10), (3773, 10), (808, 16), (161, 8), (9449, 12), (2442, 6), (1551, 16), (949, 10), (5885, 12), (2882, 15), (6226, 10), (545, 15), (9339, 10), (7557, 14), (8448, 12), (383, 9), (11, 10), (2112, 11), (5445, 15), (575, 12), (9229, 8), (2662, 10), (3223, 8), (505, 6), (9669, 14), (3553, 16), (6776, 10), (444, 11), (9889, 13), (1001, 6), (2222, 8), (99, 12), (747, 13), (616, 11), (393, 11), (737,
# ...

# %%
d = []        
for key, value in numbers_dict.items():  
    c = key, value
    d.append(c) 
    
changdu_1 = []
cishu_1=[]
changdu_2 = []
cishu_2=[]
changdu_3 = []
cishu_3=[]
changdu_4 = []
cishu_4=[]
changdu_5 = []
cishu_5=[]
for i in range(len(b)):
    cd=len(str(d[i][0]))
    shuzi = d[i][0]
    cishu = d[i][1]
    if cd == 1:
        changdu_1.append(shuzi)
        cishu_1.append(cishu)
    elif cd==2:
        changdu_2.append(shuzi)
        cishu_2.append(cishu)
    elif cd==3:
        changdu_3.append(shuzi)
        cishu_3.append(cishu)
    elif cd==4:
        changdu_4.append(shuzi)
        cishu_4.append(cishu)
    elif cd==5:
        changdu_5.append(shuzi)
        cishu_5.append(cishu)
my_sum_1 = sum (changdu_1)
my_sum_2 = sum (changdu_2)
my_sum_3 = sum (changdu_3)
my_sum_4 = sum (changdu_4)
my_sum_5 = sum (changdu_5)
my_cs_1 = sum(cishu_1)
my_cs_2 = sum(cishu_2)
my_cs_3 = sum(cishu_3)
my_cs_4 = sum(cishu_4)
my_cs_5 = sum(cishu_5)
dict_total={my_sum_1:my_cs_1}
dict_2={my_sum_2:my_cs_2}
dict_3={my_sum_3:my_cs_3}
dict_4={my_sum_4:my_cs_4}
dict_5={my_sum_5:my_cs_5}
dict_total.update(dict_2)
dict_total.update(dict_3)
dict_total.update(dict_4)
dict_total.update(dict_5)
print(sorted(dict_total.items(), key=lambda d: d[1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9d6d67561b06> in <module>()
#      14 changdu_5 = []
#      15 cishu_5=[]
# ---> 16 for i in range(len(b)):
#      17     cd=len(str(d[i][0]))
#      18     shuzi = d[i][0]
#
# TypeError: object of type 'int' has no len()

# %%
f = open('a.txt','r')
a = f.read()
b=a.replace('(','')
c=b.replace(')','')
d=c.replace(', ','\n')
numbers__1=[numb.split('\n')[0] for numb in d.split(',')]
print(numbers__1)
# Out:
